# %%
# Imports
import numpy as np
import pandas as pd
import plotly.express as px

# Inline Plots
# %matplotlib inline

# %%
# Read-in .csv file
sunspots_dataset = pd.read_csv('./data/sunspots.csv')

# Get dataframe info
sunspots_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.6+ KB

# %%
# Drop unnecessary column:
sunspots_dataset = sunspots_dataset.drop(columns=['Unnamed: 0'])

# %%
# Rename columns
sunspots_dataset.columns = ['Date', 'Monthly Mean']

# %%
# Adjust range
sunspots_dataset = sunspots_dataset.drop(sunspots_dataset.loc[:'1899-01-31'].index)

# %%
# Preview dataframe
sunspots_dataset.head()
# Out:
#             Date  Monthly Mean
# 1901  1907-06-30          67.2
# 1902  1907-07-31          82.9
# 1903  1907-08-31          90.5
# 1904  1907-09-30         141.7
# 1905  1907-10-31         109.1

# %%
plot = px.line(sunspots_dataset, x='Date', y='Monthly Mean', title='Sunspots Monthly Mean')
plot.show()

# %%
# Imports
import numpy as np
import pandas as pd
import plotly.express as px

# Inline Plots
# %matplotlib inline

# %%
# Read-in .csv file
sunspots_dataset = pd.read_csv('./data/sunspots.csv')

# Get dataframe info
sunspots_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.6+ KB

# %%
# Drop unnecessary column:
sunspots_dataset = sunspots_dataset.drop(columns=['Unnamed: 0'])

# %%
# Preview dataframe
sunspots_dataset.head()
# Out:
#          Date  Monthly Mean Total Sunspot Number
# 0  1749-01-31                               96.7
# 1  1749-02-28                              104.3
# 2  1749-03-31                              116.7
# 3  1749-04-30                               92.8
# 4  1749-05-31                              141.7

# %%
# Out:
#       index  Monthly Mean Total Sunspot Number
# 0      1900                               71.4
# 1      1901                               67.2
# 2      1902                               82.9
# 3      1903                               90.5
# 4      1904                              141.7
# ...     ...                                ...
# 1360   3260                                0.6
# 1361   3261                               14.4
# 1362   3262                               34.0
# 1363   3263                               21.8
# 1364   3264                               10.4
#
# [1365 rows x 2 columns]

# %%
# Rename columns
sunspots_dataset.columns = ['Year', 'Monthly Mean']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 2
#       1 # Rename columns
# ----> 2 sunspots_dataset.columns = ['Year', 'Monthly Mean']
#
# File ~/Software/miniconda3/envs/project2/lib/python3.9/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~/Software/miniconda3/envs/project2/lib/python3.9/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Software/miniconda3/envs/project2/lib/python3.9/site-packages/pandas/core/generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
# ...

# %%
plot = px.line(sunspots_dataset, x=sunspots_dataset.index, y='Monthly Mean', title='Sunspots Monthly Mean')
plot.show()
